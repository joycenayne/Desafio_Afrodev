# %%
import pandas as pd

# %% [markdown]
# ##### Funções Gerais

# %%
def format_string(lista):
    text = str(lista)
    text_formated = text.replace("[", "").replace("]", "").replace("'", "")
    return text_formated

# %%
atletas = pd.read_excel('../Arquivos/Athletes.xlsx')
sexo_atletas = pd.read_excel('../Arquivos/EntriesGender.xlsx')
treinadores = pd.read_excel('../Arquivos/Coaches.xlsx')
equipes = pd.read_excel('../Arquivos/Teams.xlsx')
medalhas = pd.read_excel('../Arquivos/Medals.xlsx')
# Out:
# /home/joyce/.local/lib/python3.7/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
atletas

# %%
treinadores

# %%
dic_topics = {
    '1': '1 - Atletas',
    '2': '2 - Treinadores',
    '3': '3 - Esportes',
    '4': '4 - Times',
    '5': '5 - Medalhas'
}

# %%
print("Sobre o que você deseja saber?")
topics = format_string(list(dic_topics.values()))
print("Temos perguntas sobre: {}".format(topics))
choice = input("Digite sua opção: ")

# %%
print("Sobre o que você deseja saber?")
topics = fcs.format_string(list(dic_topics.values()))
print("Temos perguntas sobre: {}".format(topics))

choice = input("Digite uma opção: ")

def path_topics(choice):
    choice = int(choice)
    if choice == 1:
        topic = dic_topics[choice]
        print(topic)

# %%
list(dic_topics.keys())

# %%
treinadores
# Out:
#                        Name                         NOC         Discipline  \
# 0           ABDELMAGID Wael                       Egypt           Football
# 1                 ABE Junya                       Japan         Volleyball
# 2             ABE Katsuhiko                       Japan         Basketball
# 3              ADAMA Cherif               Côte d'Ivoire           Football
# 4                AGEBA Yuya                       Japan         Volleyball
# ..                      ...                         ...                ...
# 389  ZAMORA PEDREIRA Javier                       Spain         Basketball
# 390      ZAMPIERI Francesca               Liechtenstein  Artistic Swimming
# 391          ZHANG Xiaohuan  People's Republic of China  Artistic Swimming
# 392              ZIJP Simon                 Netherlands             Hockey
# 393           ZONDI Nkuliso                South Africa             Hockey
#
#      Event
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# ...

# %%
treinadores[treinadores.NOC == 'Australia']

# %%
treinadores.groupby(by='NOC').count()
# Out:
#                           Name  Discipline  Event
# NOC
# Angola                       1           1      1
# Argentina                   11          11      8
# Australia                   22          22     17
# Austria                      3           3      1
# Bahrain                      1           1      1
# ...                        ...         ...    ...
# Turkey                       1           1      1
# Ukraine                      4           4      2
# United States of America    28          28     16
# Venezuela                   10          10      1
# Zambia                       2           2      1
#
# [61 rows x 3 columns]

# %%
dic_treinadore = treinadores.groupby(by='Discipline').groups

# %%
lista_treinadores = []
for chave , valor in dic_treinadore.items():
    lista_treinadores.append((chave, len(valor)))

# %%
lista_treinadores

# %%
sorted(lista_treinadores, key=lambda x: x[1], reverse=True)

# %% [markdown]
# #### Equipes

# %% [markdown]
# ##### Quantos times por esporte cada país tem

# %%
equipes
# Out:
#               Name      Discipline                         NOC  Event
# 0          Belgium  3x3 Basketball                     Belgium    Men
# 1            China  3x3 Basketball  People's Republic of China    Men
# 2            China  3x3 Basketball  People's Republic of China  Women
# 3           France  3x3 Basketball                      France  Women
# 4            Italy  3x3 Basketball                       Italy  Women
# ..             ...             ...                         ...    ...
# 738   South Africa      Water Polo                South Africa  Women
# 739          Spain      Water Polo                       Spain    Men
# 740          Spain      Water Polo                       Spain  Women
# 741  United States      Water Polo    United States of America    Men
# 742  United States      Water Polo    United States of America  Women
#
# [743 rows x 4 columns]

# %%
paises = list(equipes["NOC"].unique())
list_times_pais = []
for pais in paises:

    dict_times_pais = {
        "País":'Australia',
        "Times": []
    }
    data_times_pais = equipes[equipes.NOC == 'Australia'].groupby(by="Discipline").count()['Event']
    esportes =  list(data_times_pais.index)
    qtde_times = list(data_times_pais.values)

    for i in range(0, data_times_pais.shape[0]):
        dict_times = {}
        dict_times["Esporte"] = esportes[i]
        dict_times["Quantidade"] = qtde_times[i]
        dict_times_pais["Times"].append(dict_times)

list_times_pais.append(dict_times_pais)

# %%
list_times_pais
# Out:
# [{'País': 'Australia',
#   'Times': [{'Esporte': 'Archery', 'Quantidade': 2},
#    {'Esporte': 'Artistic Swimming', 'Quantidade': 2},
#    {'Esporte': 'Athletics', 'Quantidade': 1},
#    {'Esporte': 'Baseball/Softball', 'Quantidade': 1},
#    {'Esporte': 'Basketball', 'Quantidade': 2},
#    {'Esporte': 'Beach Volleyball', 'Quantidade': 2},
#    {'Esporte': 'Cycling Track', 'Quantidade': 5},
#    {'Esporte': 'Football', 'Quantidade': 2},
#    {'Esporte': 'Hockey', 'Quantidade': 2},
#    {'Esporte': 'Rhythmic Gymnastics', 'Quantidade': 1},
#    {'Esporte': 'Rugby Sevens', 'Quantidade': 2},
#    {'Esporte': 'Swimming', 'Quantidade': 7},
#    {'Esporte': 'Table Tennis', 'Quantidade': 3},
#    {'Esporte': 'Triathlon', 'Quantidade': 1},
#    {'Esporte': 'Water Polo', 'Quantidade': 2}]}]

# %% [markdown]
# #### Medalhas

# %% [markdown]
# ##### Total de medalhas por país

# %%
teste = list (medalhas[medalhas["Rank"] <= 3]["Total_Medals"])

# %%
teste.append('e')
teste
# Out:
# [113, 88, 58, 'e', 'e']

# %%
brazil = medalhas[medalhas["Team/NOC"] == "Brazil"]["Team/NOC"].values.tolist()
brazil + [1, 2,3]
# Out:
# ['Brazil', 1, 2, 3]

# %%
medalhas[medalhas["Team/NOC"] == "Brazil"]["Rank"]
# Out:
# 11    12
# Name: Rank, dtype: int64

# %%
medalhas["Total_Medals"] = 0
for index, row in medalhas.iterrows():
    medalhas.loc[index,"Total_Medals"]= row["Gold"] + row["Silver"] + row["Bronze"]

# %%
medalhas.co
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total_Medals
# 0      1    United States of America    39      41      33           113
# 1      2  People's Republic of China    38      32      18            88
# 2      3                       Japan    27      14      17            58
# 3      4               Great Britain    22      21      22            65
# 4      5                         ROC    20      28      23            71
# ..   ...                         ...   ...     ...     ...           ...
# 88    86                       Ghana     0       0       1             1
# 89    86                     Grenada     0       0       1             1
# 90    86                      Kuwait     0       0       1             1
# 91    86         Republic of Moldova     0       0       1             1
# 92    86        Syrian Arab Republic     0       0       1             1
#
# [93 rows x 6 columns]

# %%
list_total_medales = []
for _, row in medalhas.iterrows():
    dic_medalhas = {}
    dic_medalhas["País"] = row["Team/NOC"]
    dic_medalhas["Total_Medalhas"] = row["Total_Medals"]
    list_total_medales.append(dic_medalhas)
print(list_total_medales)
# Out:
# [{'País': 'United States of America', 'Total_Medalhas': 113}, {'País': "People's Republic of China", 'Total_Medalhas': 88}, {'País': 'Japan', 'Total_Medalhas': 58}, {'País': 'Great Britain', 'Total_Medalhas': 65}, {'País': 'ROC', 'Total_Medalhas': 71}, {'País': 'Australia', 'Total_Medalhas': 46}, {'País': 'Netherlands', 'Total_Medalhas': 36}, {'País': 'France', 'Total_Medalhas': 33}, {'País': 'Germany', 'Total_Medalhas': 37}, {'País': 'Italy', 'Total_Medalhas': 40}, {'País': 'Canada', 'Total_Medalhas': 24}, {'País': 'Brazil', 'Total_Medalhas': 21}, {'País': 'New Zealand', 'Total_Medalhas': 20}, {'País': 'Cuba', 'Total_Medalhas': 15}, {'País': 'Hungary', 'Total_Medalhas': 20}, {'País': 'Republic of Korea', 'Total_Medalhas': 20}, {'País': 'Poland', 'Total_Medalhas': 14}, {'País': 'Czech Republic', 'Total_Medalhas': 11}, {'País': 'Kenya', 'Total_Medalhas': 10}, {'País': 'Norway', 'Total_Medalhas': 8}, {'País': 'Jamaica', 'Total_Medalhas': 9}, {'País': 'Spain', 'Total_Medalhas': 17}, {'P
# ...

# %%
pais = medalhas[medalhas['Gold'] == 0]

# %%
def country_max_gold(data):
    country = data[data["Silver"] == data["Silver"].max()]["Team/NOC"]
    print(f"O país com mais medalhas de ouro é {country}")
# Out:
#     Rank              Team/NOC  Gold  Silver  Bronze  Total_Medals
# 65    66              Colombia     0       4       1             5
# 66    67            Azerbaijan     0       3       4             7
# 67    68    Dominican Republic     0       3       2             5
# 68    69               Armenia     0       2       2             4
# 69    70            Kyrgyzstan     0       2       1             3
# 70    71              Mongolia     0       1       3             4
# 71    72             Argentina     0       1       2             3
# 72    72            San Marino     0       1       2             3
# 73    74                Jordan     0       1       1             2
# 74    74              Malaysia     0       1       1             2
# 75    74               Nigeria     0       1       1             2
# 76    77               Bahrain     0       1       0             1
# 77    77          Saudi Arabia     0       1       0             1
# ...

# %%
country = medalhas[medalhas["Gold"] == medalhas["Gold"].min()]["Team/NOC"]

# %%
list(country)
# Out:
# ['Colombia',
#  'Azerbaijan',
#  'Dominican Republic',
#  'Armenia',
#  'Kyrgyzstan',
#  'Mongolia',
#  'Argentina',
#  'San Marino',
#  'Jordan',
#  'Malaysia',
#  'Nigeria',
#  'Bahrain',
#  'Saudi Arabia',
#  'Lithuania',
#  'North Macedonia',
#  'Namibia',
#  'Turkmenistan',
#  'Kazakhstan',
#  'Mexico',
#  'Finland',
#  'Botswana',
#  'Burkina Faso',
#  "Côte d'Ivoire",
#  'Ghana',
#  'Grenada',
#  'Kuwait',
#  'Republic of Moldova',
#  'Syrian Arab Republic']

# %%
medalhas.sort_values(by="Total_Medals", ascending=False)
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total_Medals
# 0      1    United States of America    39      41      33           113
# 1      2  People's Republic of China    38      32      18            88
# 4      5                         ROC    20      28      23            71
# 3      4               Great Britain    22      21      22            65
# 2      3                       Japan    27      14      17            58
# ..   ...                         ...   ...     ...     ...           ...
# 77    77                Saudi Arabia     0       1       0             1
# 76    77                     Bahrain     0       1       0             1
# 62    63                     Bermuda     1       0       0             1
# 63    63                     Morocco     1       0       0             1
# 92    86        Syrian Arab Republic     0       0       1             1
#
# [93 rows x 6 columns]

# %%
medalhas
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total_Medals
# 0      1    United States of America    39      41      33           113
# 1      2  People's Republic of China    38      32      18            88
# 2      3                       Japan    27      14      17            58
# 3      4               Great Britain    22      21      22            65
# 4      5                         ROC    20      28      23            71
# ..   ...                         ...   ...     ...     ...           ...
# 88    86                       Ghana     0       0       1             1
# 89    86                     Grenada     0       0       1             1
# 90    86                      Kuwait     0       0       1             1
# 91    86         Republic of Moldova     0       0       1             1
# 92    86        Syrian Arab Republic     0       0       1             1
#
# [93 rows x 6 columns]

# %%
medalhas
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total_Medals
# 0      1    United States of America    39      41      33           113
# 1      2  People's Republic of China    38      32      18            88
# 2      3                       Japan    27      14      17            58
# 3      4               Great Britain    22      21      22            65
# 4      5                         ROC    20      28      23            71
# ..   ...                         ...   ...     ...     ...           ...
# 88    86                       Ghana     0       0       1             1
# 89    86                     Grenada     0       0       1             1
# 90    86                      Kuwait     0       0       1             1
# 91    86         Republic of Moldova     0       0       1             1
# 92    86        Syrian Arab Republic     0       0       1             1
#
# [93 rows x 6 columns]

# %%
medalhas['var_1'] = medalhas["Gold"] + medalhas["Silver"] + medalhas["Bronze"]

# %%
medalhas
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total_Medals  \
# 0      1    United States of America    39      41      33           113
# 1      2  People's Republic of China    38      32      18            88
# 2      3                       Japan    27      14      17            58
# 3      4               Great Britain    22      21      22            65
# 4      5                         ROC    20      28      23            71
# ..   ...                         ...   ...     ...     ...           ...
# 88    86                       Ghana     0       0       1             1
# 89    86                     Grenada     0       0       1             1
# 90    86                      Kuwait     0       0       1             1
# 91    86         Republic of Moldova     0       0       1             1
# 92    86        Syrian Arab Republic     0       0       1             1
#
#     var_1
# 0     113
# 1      88
# 2      58
# 3      65
# 4      71
# ..    ...
# ...

# %%
medalhas[medalhas.Silver == medalhas.Silver.max()]['Team/NOC'][0]
# Out:
# 'United States of America'

# %%
to_json = medalhas.loc[:, ['Team/NOC', 'Total_Medals']]
to_json
# Out:
# [('United States of America', 113),
#  ("People's Republic of China", 88),
#  ('Japan', 58),
#  ('Great Britain', 65),
#  ('ROC', 71),
#  ('Australia', 46),
#  ('Netherlands', 36),
#  ('France', 33),
#  ('Germany', 37),
#  ('Italy', 40),
#  ('Canada', 24),
#  ('Brazil', 21),
#  ('New Zealand', 20),
#  ('Cuba', 15),
#  ('Hungary', 20),
#  ('Republic of Korea', 20),
#  ('Poland', 14),
#  ('Czech Republic', 11),
#  ('Kenya', 10),
#  ('Norway', 8),
#  ('Jamaica', 9),
#  ('Spain', 17),
#  ('Sweden', 9),
#  ('Switzerland', 13),
#  ('Denmark', 11),
#  ('Croatia', 8),
#  ('Islamic Republic of Iran', 7),
#  ('Serbia', 9),
#  ('Belgium', 7),
#  ('Bulgaria', 6),
#  ('Slovenia', 5),
#  ('Uzbekistan', 5),
#  ('Georgia', 8),
#  ('Chinese Taipei', 12),
#  ('Turkey', 13),
#  ('Greece', 4),
#  ('Uganda', 4),
#  ('Ecuador', 3),
#  ('Ireland', 4),
#  ('Israel', 4),
#  ('Qatar', 3),
#  ('Bahamas', 2),
#  ('Kosovo', 2),
#  ('Ukraine', 19),
#  ('Belarus', 7),
#  ('Romania', 4),
#  ('Venezuela', 4),
# ...

# %%
stra = to_json.to_json(orient='table', index=False)

# %%
print(stra)
# Out:
# {"schema":{"fields":[{"name":"Team\/NOC","type":"string"},{"name":"Total_Medals","type":"integer"}],"pandas_version":"0.20.0"},"data":[{"Team\/NOC":"United States of America","Total_Medals":113},{"Team\/NOC":"People's Republic of China","Total_Medals":88},{"Team\/NOC":"Japan","Total_Medals":58},{"Team\/NOC":"Great Britain","Total_Medals":65},{"Team\/NOC":"ROC","Total_Medals":71},{"Team\/NOC":"Australia","Total_Medals":46},{"Team\/NOC":"Netherlands","Total_Medals":36},{"Team\/NOC":"France","Total_Medals":33},{"Team\/NOC":"Germany","Total_Medals":37},{"Team\/NOC":"Italy","Total_Medals":40},{"Team\/NOC":"Canada","Total_Medals":24},{"Team\/NOC":"Brazil","Total_Medals":21},{"Team\/NOC":"New Zealand","Total_Medals":20},{"Team\/NOC":"Cuba","Total_Medals":15},{"Team\/NOC":"Hungary","Total_Medals":20},{"Team\/NOC":"Republic of Korea","Total_Medals":20},{"Team\/NOC":"Poland","Total_Medals":14},{"Team\/NOC":"Czech Republic","Total_Medals":11},{"Team\/NOC":"Kenya","Total_Medals":10},{"Team\/NOC"
# ...

# %%
vvv = [(row["Team/NOC"], row["Total_Medals"]) for _, row in medalhas.iterrows()]

# %%
vvv
# Out:
# [('United States of America', 113),
#  ("People's Republic of China", 88),
#  ('Japan', 58),
#  ('Great Britain', 65),
#  ('ROC', 71),
#  ('Australia', 46),
#  ('Netherlands', 36),
#  ('France', 33),
#  ('Germany', 37),
#  ('Italy', 40),
#  ('Canada', 24),
#  ('Brazil', 21),
#  ('New Zealand', 20),
#  ('Cuba', 15),
#  ('Hungary', 20),
#  ('Republic of Korea', 20),
#  ('Poland', 14),
#  ('Czech Republic', 11),
#  ('Kenya', 10),
#  ('Norway', 8),
#  ('Jamaica', 9),
#  ('Spain', 17),
#  ('Sweden', 9),
#  ('Switzerland', 13),
#  ('Denmark', 11),
#  ('Croatia', 8),
#  ('Islamic Republic of Iran', 7),
#  ('Serbia', 9),
#  ('Belgium', 7),
#  ('Bulgaria', 6),
#  ('Slovenia', 5),
#  ('Uzbekistan', 5),
#  ('Georgia', 8),
#  ('Chinese Taipei', 12),
#  ('Turkey', 13),
#  ('Greece', 4),
#  ('Uganda', 4),
#  ('Ecuador', 3),
#  ('Ireland', 4),
#  ('Israel', 4),
#  ('Qatar', 3),
#  ('Bahamas', 2),
#  ('Kosovo', 2),
#  ('Ukraine', 19),
#  ('Belarus', 7),
#  ('Romania', 4),
#  ('Venezuela', 4),
# ...

# %%
format_string(vvv)
# Out:
# '(United States of America, 113), ("Peoples Republic of China", 88), (Japan, 58), (Great Britain, 65), (ROC, 71), (Australia, 46), (Netherlands, 36), (France, 33), (Germany, 37), (Italy, 40), (Canada, 24), (Brazil, 21), (New Zealand, 20), (Cuba, 15), (Hungary, 20), (Republic of Korea, 20), (Poland, 14), (Czech Republic, 11), (Kenya, 10), (Norway, 8), (Jamaica, 9), (Spain, 17), (Sweden, 9), (Switzerland, 13), (Denmark, 11), (Croatia, 8), (Islamic Republic of Iran, 7), (Serbia, 9), (Belgium, 7), (Bulgaria, 6), (Slovenia, 5), (Uzbekistan, 5), (Georgia, 8), (Chinese Taipei, 12), (Turkey, 13), (Greece, 4), (Uganda, 4), (Ecuador, 3), (Ireland, 4), (Israel, 4), (Qatar, 3), (Bahamas, 2), (Kosovo, 2), (Ukraine, 19), (Belarus, 7), (Romania, 4), (Venezuela, 4), (India, 7), (Hong Kong, China, 6), (Philippines, 4), (Slovakia, 4), (South Africa, 3), (Austria, 7), (Egypt, 6), (Indonesia, 5), (Ethiopia, 4), (Portugal, 4), (Tunisia, 2), (Estonia, 2), (Fiji, 2), (Latvia, 2), (Thailand, 2), (Bermuda, 1
# ...

# %%
# Out:
# ['Archery',
#  'Artistic Swimming',
#  'Athletics',
#  'Baseball/Softball',
#  'Basketball',
#  'Beach Volleyball',
#  'Cycling Track',
#  'Football',
#  'Hockey',
#  'Rhythmic Gymnastics',
#  'Rugby Sevens',
#  'Swimming',
#  'Table Tennis',
#  'Triathlon',
#  'Water Polo']

# %%
atletas = pd.read_excel('../Arquivos/Athletes.xlsx')
sexo_atletas = pd.read_excel('../Arquivos/EntriesGender.xlsx')
treinadores = pd.read_excel('../Arquivos/Coaches.xlsx')
equipes = pd.read_excel('../Arquivos/Teams.xlsx')
medalhas = pd.read_excel('../Arquivos/Medals.xlsx')

# %%
atletas
# Out:
#                         Name      NOC           Discipline
# 0            AALERUD Katrine   Norway         Cycling Road
# 1                ABAD Nestor    Spain  Artistic Gymnastics
# 2          ABAGNALE Giovanni    Italy               Rowing
# 3             ABALDE Alberto    Spain           Basketball
# 4              ABALDE Tamara    Spain           Basketball
# ...                      ...      ...                  ...
# 11080  ZWICKER Martin Detlef  Germany               Hockey
# 11081      ZWOLINSKA Klaudia   Poland         Canoe Slalom
# 11082           ZYKOVA Yulia      ROC             Shooting
# 11083      ZYUZINA Ekaterina      ROC              Sailing
# 11084        ZYZANSKA Sylwia   Poland              Archery
#
# [11085 rows x 3 columns]

# %%
print(treinadores.groupby(by="Discipline").groups)
# Out:
# {'Artistic Swimming': [26, 35, 43, 45, 56, 57, 58, 59, 60, 67, 71, 79, 82, 84, 91, 92, 93, 99, 100, 102, 103, 106, 113, 115, 116, 122, 126, 127, 138, 141, 159, 172, 176, 180, 202, 206, 217, 220, 246, 250, 256, 257, 258, 262, 263, 287, 288, 291, 292, 304, 305, 327, 339, 344, 345, 346, 347, 350, 352, 353, 357, 362, 367, 372, 375, 376, 388, 390, 391], 'Baseball/Softball': [7, 25, 31, 52, 53, 61, 83, 97, 108, 109, 120, 143, 144, 155, 182, 183, 185, 196, 267, 282, 293, 335, 351, 363, 378, 385], 'Basketball': [2, 10, 13, 29, 30, 37, 40, 42, 55, 62, 64, 80, 81, 85, 87, 88, 89, 95, 105, 110, 121, 123, 129, 134, 135, 140, 146, 153, 154, 163, 164, 169, 170, 171, 181, 184, 211, 214, 219, 221, 223, 225, 228, 237, 244, 248, 249, 251, 253, 254, 260, 261, 266, 278, 281, 290, 294, 299, 310, 313, 315, 321, 322, 323, 326, 340, 342, 355, 360, 365, 366, 383, 384, 389], 'Football': [0, 3, 11, 12, 14, 15, 18, 21, 28, 47, 54, 73, 74, 101, 124, 133, 136, 142, 148, 150, 156, 158, 166, 175, 178, 179, 187, 188
# ...

# %%
li_a = list(atletas.Discipline.unique())

# %%
print(li_a)
# Out:
# ['Cycling Road', 'Artistic Gymnastics', 'Rowing', 'Basketball', 'Handball', 'Swimming', 'Karate', 'Wrestling', 'Rhythmic Gymnastics', 'Baseball/Softball', 'Athletics', 'Artistic Swimming', 'Judo', 'Shooting', 'Table Tennis', 'Football', 'Taekwondo', 'Fencing', 'Badminton', 'Boxing', 'Weightlifting', 'Archery', 'Diving', 'Beach Volleyball', 'Sailing', 'Hockey', 'Trampoline Gymnastics', 'Marathon Swimming', 'Triathlon', 'Canoe Slalom', 'Water Polo', 'Surfing', 'Canoe Sprint', 'Cycling BMX Racing', 'Rugby Sevens', 'Volleyball', 'Equestrian', 'Tennis', 'Cycling Track', 'Golf', 'Skateboarding', 'Modern Pentathlon', 'Cycling Mountain Bike', '3x3 Basketball', 'Cycling BMX Freestyle', 'Sport Climbing']

# %%
print(li_s)
# Out:
# ['3x3 Basketball', 'Archery', 'Artistic Gymnastics', 'Artistic Swimming', 'Athletics', 'Badminton', 'Baseball/Softball', 'Basketball', 'Beach Volleyball', 'Boxing', 'Canoe Slalom', 'Canoe Sprint', 'Cycling BMX Freestyle', 'Cycling BMX Racing', 'Cycling Mountain Bike', 'Cycling Road', 'Cycling Track', 'Diving', 'Equestrian', 'Fencing', 'Football', 'Golf', 'Handball', 'Hockey', 'Judo', 'Karate', 'Marathon Swimming', 'Modern Pentathlon', 'Rhythmic Gymnastics', 'Rowing', 'Rugby Sevens', 'Sailing', 'Shooting', 'Skateboarding', 'Sport Climbing', 'Surfing', 'Swimming', 'Table Tennis', 'Taekwondo', 'Tennis', 'Trampoline Gymnastics', 'Triathlon', 'Volleyball', 'Water Polo', 'Weightlifting', 'Wrestling']

# %%
li_s = list(sexo_atletas.Discipline.unique())

# %%
li_a == li_s
# Out:
# True

# %%
li_a = sorted(li_a)
li_s = sorted(li_s)

# %%
equipes[equipes.Name == "Belgium"]
# Out:
#         Name           Discipline      NOC                   Event
# 0    Belgium       3x3 Basketball  Belgium                     Men
# 69   Belgium  Artistic Gymnastics  Belgium            Women's Team
# 128  Belgium            Athletics  Belgium    4 x 400m Relay Mixed
# 129  Belgium            Athletics  Belgium    Men's 4 x 400m Relay
# 130  Belgium            Athletics  Belgium  Women's 4 x 400m Relay
# 219  Belgium           Basketball  Belgium                   Women
# 294  Belgium        Cycling Track  Belgium           Men's Madison
# 295  Belgium        Cycling Track  Belgium         Women's Madison
# 460  Belgium               Hockey  Belgium                     Men
# 681  Belgium            Triathlon  Belgium             Mixed Relay

# %%
def total_teams_by_sports_country(data):
    countries = list(data["NOC"].unique())
    list_teams_countries = []
    
    for country in countries:
        dict_teams_country = {
            "País": country,
            "Times": []
        }

        data_teams_country = data[data.NOC == country].groupby(by="Discipline").count()['Event']
        sports =  list(data_teams_country.index)
        count_times = list(data_teams_country.values)

        for index in range(0, data_teams_country.shape[0]):
            dict_teams = {}
            dict_teams["Esporte"] = sports[index]
            dict_teams["Quantidade"] = count_times[index]
            dict_teams_country["Times"].append(dict_teams)
        list_teams_countries.append(dict_teams_country)
    print(f"A seguir, quantidade de times por esporte em cada país: {list_teams_countries}")

# %%
total_teams_by_sports_country(equipes[equipes.Name == "Belgium"])
# Out:
# A seguir, quantidade de times por esporte em cada país: [{'País': 'Belgium', 'Times': [{'Esporte': '3x3 Basketball', 'Quantidade': 1}, {'Esporte': 'Artistic Gymnastics', 'Quantidade': 1}, {'Esporte': 'Athletics', 'Quantidade': 3}, {'Esporte': 'Basketball', 'Quantidade': 1}, {'Esporte': 'Cycling Track', 'Quantidade': 2}, {'Esporte': 'Hockey', 'Quantidade': 1}, {'Esporte': 'Triathlon', 'Quantidade': 1}]}]

# %%
medals = medalhas[medalhas["Gold"] == medalhas["Gold"].max()]

# %%
medalhas[medalhas["Team/NOC"] == 'Brazil']
# Out:
#     Rank Team/NOC  Gold  Silver  Bronze  Total_Medals  var_1
# 11    12   Brazil     7       6       8            21     21

# %%
atletas[atletas.NOC == 'Brazil'].groupby(by='Discipline').group_keys()
# Out:
# True

# %%
treinadores[treinadores.NOC == 'Brazil']
# Out:
#                            Name     NOC    Discipline  Event
# 39            BRODERICK William  Brazil  Rugby Sevens  Women
# 69              DAL ZOTTO Renan  Brazil    Volleyball    Men
# 76   de OLIVEIRA Marcus Ricardo  Brazil      Handball    Men
# 86      DUENAS de GALARZA Jorge  Brazil      Handball  Women
# 147      GUIMARAES Jose Roberto  Brazil    Volleyball  Women
# 175               JARDINE Andre  Brazil      Football    Men
# 343        SUNDHAGE Pia Mariane  Brazil      Football  Women

# %%
df = atletas[atletas.Discipline == 'Athletics'].groupby(by="NOC").count()
df
# Out:
#                          Name  Discipline
# NOC
# Afghanistan                 2           2
# Albania                     1           1
# Algeria                     8           8
# American Samoa              1           1
# Andorra                     1           1
# ...                       ...         ...
# Virgin Islands, British     2           2
# Virgin Islands, US          1           1
# Yemen                       1           1
# Zambia                      2           2
# Zimbabwe                    1           1
#
# [195 rows x 2 columns]

# %%
df[df.Discipline == df.Discipline.max()].values[0][0]
# Out:
# 144

# %%
br = 'BR'
eua = 'eua'

# %%
lista = [br, eua]

# %%
lista
# Out:
# ['BR', 'eua']
